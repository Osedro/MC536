# %% [markdown]
# # World Health Organization Data
#
# ## Global Health Observatory
#
# * [Data query API](https://apps.who.int/gho/data/node.resources.api)
# * [GHO OData API ](https://www.who.int/data/gho/info/gho-odata-api)
#
# Exemplos de API: [https://www.who.int/data/gho/info/athena-api-examples](https://www.who.int/data/gho/info/athena-api-examples).
#
# Para se determinar o tipo de informação para acesso veja a [lista de dimensões e códigos](https://apps.who.int/gho/athena/api/GHO). Utilize o código disponível no campo `<Code label="">`. Por exemplo, no campo `<Code Label="WHOSIS_000001">` é possível encontrar o código `WHOSIS_000001` que indica `Life expectancy at birth (years)`.
#
# Depois de estabelecida a informação, podem ser configurados parâmetros, com o sufixo `?` depois da URL. Os parâmetros são separados por `&`.
#
# Os códigos dos países são encontrados em: [https://apps.who.int/gho/athena/api/COUNTRY](https://apps.who.int/gho/athena/api/COUNTRY).

# %% [markdown]
# ## Importando dados em JSON no Python
#
# ![JSON](json.png)

# %%
import io
import requests
import json
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA&format=json"
js = requests.get(url).content
print(js.decode("utf-8"))

# %% [markdown]
# ### Mostrando o Copyright

# %%
import io
import requests
import json
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA&format=json"
data = requests.get(url)
js = data.json()
print(js["copyright"])
# Out:
# (c) World Health Organization

# %% [markdown]
# ## Importando dados em CSV no Python
#
# ![CSV](csv.png)

# %%
import pandas as pd
import io
import requests
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA&format=csv"
data = requests.get(url).content
csv = pd.read_csv(io.StringIO(data.decode("utf-8")))
print(csv)
# Out:
#               GHO PUBLISHSTATE  YEAR REGION COUNTRY   SEX  Display Value  \
# 0   WHOSIS_000001    PUBLISHED  2000    AMR     BRA   MLE           66.1
# 1   WHOSIS_000001    PUBLISHED  2001    AMR     BRA   MLE           66.5
# 2   WHOSIS_000001    PUBLISHED  2002    AMR     BRA   MLE           66.9
# 3   WHOSIS_000001    PUBLISHED  2003    AMR     BRA   MLE           67.3
# 4   WHOSIS_000001    PUBLISHED  2004    AMR     BRA   MLE           67.6
# 5   WHOSIS_000001    PUBLISHED  2005    AMR     BRA   MLE           68.4
# 6   WHOSIS_000001    PUBLISHED  2006    AMR     BRA   MLE           68.7
# 7   WHOSIS_000001    PUBLISHED  2007    AMR     BRA   MLE           69.1
# 8   WHOSIS_000001    PUBLISHED  2008    AMR     BRA   MLE           69.3
# 9   WHOSIS_000001    PUBLISHED  2009    AMR     BRA   MLE           69.5
# 10  WHOSIS_000001    PUBLISHED  2010    AMR     BRA   MLE           69.7
# 11  WHOSIS_000001    PUBLISHED  2011    AMR     BRA   MLE           69.9
# 12  WHOSIS_000001    PUBLISHED  2012    AMR     BRA   MLE           70.4
# 13  WHOSIS_000001    PUBLISHED  2013    AMR     BRA   MLE           70.7
# 14  WHOSIS_000001    PUBLISHED  2014    AMR     BRA   MLE           71.0
# 15  WHOSIS_000001    PUBLISHED  2015    AMR     BRA   MLE           71.2
# 16  WHOSIS_000001    PUBLISHED  2016    AMR     BRA   MLE           71.4
# 17  WHOSIS_000001    PUBLISHED  2000    AMR     BRA  FMLE           73.9
# 18  WHOSIS_000001    PUBLISHED  2001    AMR     BRA  FMLE           74.4
# 19  WHOSIS_000001    PUBLISHED  2002    AMR     BRA  FMLE           74.7
# 20  WHOSIS_000001    PUBLISHED  2003    AMR     BRA  FMLE           75.1
# 21  WHOSIS_000001    PUBLISHED  2004    AMR     BRA  FMLE           75.3
# 22  WHOSIS_000001    PUBLISHED  2005    AMR     BRA  FMLE           76.0
# 23  WHOSIS_000001    PUBLISHED  2006    AMR     BRA  FMLE           76.2
# 24  WHOSIS_000001    PUBLISHED  2007    AMR     BRA  FMLE           76.6
# 25  WHOSIS_000001    PUBLISHED  2008    AMR     BRA  FMLE           76.8
# 26  WHOSIS_000001    PUBLISHED  2009    AMR     BRA  FMLE           77.0
# 27  WHOSIS_000001    PUBLISHED  2010    AMR     BRA  FMLE           77.1
# 28  WHOSIS_000001    PUBLISHED  2011    AMR     BRA  FMLE           77.3
# 29  WHOSIS_000001    PUBLISHED  2012    AMR     BRA  FMLE           77.8
# 30  WHOSIS_000001    PUBLISHED  2013    AMR     BRA  FMLE           78.1
# 31  WHOSIS_000001    PUBLISHED  2014    AMR     BRA  FMLE           78.5
# 32  WHOSIS_000001    PUBLISHED  2015    AMR     BRA  FMLE           78.6
# 33  WHOSIS_000001    PUBLISHED  2016    AMR     BRA  FMLE           78.9
# 34  WHOSIS_000001    PUBLISHED  2000    AMR     BRA  BTSX           69.9
# 35  WHOSIS_000001    PUBLISHED  2001    AMR     BRA  BTSX           70.4
# 36  WHOSIS_000001    PUBLISHED  2002    AMR     BRA  BTSX           70.7
# 37  WHOSIS_000001    PUBLISHED  2003    AMR     BRA  BTSX           71.1
# 38  WHOSIS_000001    PUBLISHED  2004    AMR     BRA  BTSX           71.4
# 39  WHOSIS_000001    PUBLISHED  2005    AMR     BRA  BTSX           72.1
# 40  WHOSIS_000001    PUBLISHED  2006    AMR     BRA  BTSX           72.4
# 41  WHOSIS_000001    PUBLISHED  2007    AMR     BRA  BTSX           72.8
# 42  WHOSIS_000001    PUBLISHED  2008    AMR     BRA  BTSX           73.0
# 43  WHOSIS_000001    PUBLISHED  2009    AMR     BRA  BTSX           73.2
# 44  WHOSIS_000001    PUBLISHED  2010    AMR     BRA  BTSX           73.3
# 45  WHOSIS_000001    PUBLISHED  2011    AMR     BRA  BTSX           73.6
# 46  WHOSIS_000001    PUBLISHED  2012    AMR     BRA  BTSX           74.0
# 47  WHOSIS_000001    PUBLISHED  2013    AMR     BRA  BTSX           74.3
# 48  WHOSIS_000001    PUBLISHED  2014    AMR     BRA  BTSX           74.7
# 49  WHOSIS_000001    PUBLISHED  2015    AMR     BRA  BTSX           74.9
# 50  WHOSIS_000001    PUBLISHED  2016    AMR     BRA  BTSX           75.1
#
#      Numeric  Low  High                                   Comments
# 0   66.07471  NaN   NaN  WHO life table method: Vital registration
# 1   66.52457  NaN   NaN  WHO life table method: Vital registration
# 2   66.91918  NaN   NaN  WHO life table method: Vital registration
# 3   67.29173  NaN   NaN  WHO life table method: Vital registration
# 4   67.60056  NaN   NaN  WHO life table method: Vital registration
# 5   68.37924  NaN   NaN  WHO life table method: Vital registration
# 6   68.73450  NaN   NaN  WHO life table method: Vital registration
# 7   69.08048  NaN   NaN  WHO life table method: Vital registration
# 8   69.28578  NaN   NaN  WHO life table method: Vital registration
# 9   69.52082  NaN   NaN  WHO life table method: Vital registration
# 10  69.65516  NaN   NaN  WHO life table method: Vital registration
# 11  69.94624  NaN   NaN  WHO life table method: Vital registration
# 12  70.35987  NaN   NaN  WHO life table method: Vital registration
# 13  70.65484  NaN   NaN  WHO life table method: Vital registration
# 14  71.01771  NaN   NaN  WHO life table method: Vital registration
# 15  71.18656  NaN   NaN  WHO life table method: Vital registration
# 16  71.44357  NaN   NaN  WHO life table method: Vital registration
# 17  73.90521  NaN   NaN  WHO life table method: Vital registration
# 18  74.38860  NaN   NaN  WHO life table method: Vital registration
# 19  74.69605  NaN   NaN  WHO life table method: Vital registration
# 20  75.07509  NaN   NaN  WHO life table method: Vital registration
# 21  75.31032  NaN   NaN  WHO life table method: Vital registration
# 22  75.96941  NaN   NaN  WHO life table method: Vital registration
# 23  76.22217  NaN   NaN  WHO life table method: Vital registration
# 24  76.57856  NaN   NaN  WHO life table method: Vital registration
# 25  76.83010  NaN   NaN  WHO life table method: Vital registration
# 26  76.98610  NaN   NaN  WHO life table method: Vital registration
# 27  77.12752  NaN   NaN  WHO life table method: Vital registration
# 28  77.34761  NaN   NaN  WHO life table method: Vital registration
# 29  77.80472  NaN   NaN  WHO life table method: Vital registration
# 30  78.11185  NaN   NaN  WHO life table method: Vital registration
# 31  78.47605  NaN   NaN  WHO life table method: Vital registration
# 32  78.62926  NaN   NaN  WHO life table method: Vital registration
# 33  78.88345  NaN   NaN  WHO life table method: Vital registration
# 34  69.89580  NaN   NaN  WHO life table method: Vital registration
# 35  70.36314  NaN   NaN  WHO life table method: Vital registration
# 36  70.72389  NaN   NaN  WHO life table method: Vital registration
# 37  71.09914  NaN   NaN  WHO life table method: Vital registration
# 38  71.37670  NaN   NaN  WHO life table method: Vital registration
# 39  72.11478  NaN   NaN  WHO life table method: Vital registration
# 40  72.42526  NaN   NaN  WHO life table method: Vital registration
# 41  72.77940  NaN   NaN  WHO life table method: Vital registration
# 42  73.00681  NaN   NaN  WHO life table method: Vital registration
# 43  73.20933  NaN   NaN  WHO life table method: Vital registration
# 44  73.34766  NaN   NaN  WHO life table method: Vital registration
# 45  73.60731  NaN   NaN  WHO life table method: Vital registration
# 46  74.04764  NaN   NaN  WHO life table method: Vital registration
# 47  74.34875  NaN   NaN  WHO life table method: Vital registration
# 48  74.71724  NaN   NaN  WHO life table method: Vital registration
# 49  74.88107  NaN   NaN  WHO life table method: Vital registration
# 50  75.13705  NaN   NaN  WHO life table method: Vital registration

# %% [markdown]
# # Mostrando o Copyright

# %% [markdown]
# # Importando dados em XML no Python
#
# ![XML](xml.png)

# %%
import io
import requests
import xml.etree.ElementTree as et
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA"
data = requests.get(url).content
x = et.parse(io.StringIO(data.decode("utf-8")))
print(x)
# Out:
# <xml.etree.ElementTree.ElementTree object at 0x7ff5cb490b50>

# %% [markdown]
# # Mostrando o Copyright

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %%
import io
import requests
import json
url = 'https://maps2.dcgis.dc.gov/dcgis/rest/services/FEEDS/MPD/MapServer/2/query?where=1%3D1&outFields=*&outSR=4326&f=json'
request = requests.get(url)
js = request.json()
print(js["displayFieldName"])
print(js["fieldAliases"])
print(js)
# Out:
# CCN
# {'CCN': 'CCN', 'REPORT_DAT': 'REPORT_DATE', 'SHIFT': 'SHIFT', 'METHOD': 'METHOD', 'OFFENSE': 'OFFENSE', 'BLOCK': 'BLOCK', 'XBLOCK': 'XBLOCK', 'YBLOCK': 'YBLOCK', 'WARD': 'WARD', 'ANC': 'ANC', 'DISTRICT': 'DISTRICT', 'PSA': 'PSA', 'NEIGHBORHOOD_CLUSTER': 'NEIGHBORHOOD_CLUSTER', 'BLOCK_GROUP': 'BLOCK_GROUP', 'CENSUS_TRACT': 'CENSUS_TRACT', 'VOTING_PRECINCT': 'VOTING_PRECINCT', 'LATITUDE': 'LATITUDE', 'LONGITUDE': 'LONGITUDE', 'BID': 'BID', 'START_DATE': 'START_DATE', 'END_DATE': 'END_DATE', 'OBJECTID': 'OBJECTID', 'OCTO_RECORD_ID': 'OCTO_RECORD_ID'}
# {'displayFieldName': 'CCN', 'fieldAliases': {'CCN': 'CCN', 'REPORT_DAT': 'REPORT_DATE', 'SHIFT': 'SHIFT', 'METHOD': 'METHOD', 'OFFENSE': 'OFFENSE', 'BLOCK': 'BLOCK', 'XBLOCK': 'XBLOCK', 'YBLOCK': 'YBLOCK', 'WARD': 'WARD', 'ANC': 'ANC', 'DISTRICT': 'DISTRICT', 'PSA': 'PSA', 'NEIGHBORHOOD_CLUSTER': 'NEIGHBORHOOD_CLUSTER', 'BLOCK_GROUP': 'BLOCK_GROUP', 'CENSUS_TRACT': 'CENSUS_TRACT', 'VOTING_PRECINCT': 'VOTING_PRECINCT', 'LATITUDE': 'LATITUDE', 'LONGITUDE': 'LONGITUDE', 'BID': 'BID', 'START_DATE': 'START_DATE', 'END_DATE': 'END_DATE', 'OBJECTID': 'OBJECTID', 'OCTO_RECORD_ID': 'OCTO_RECORD_ID'}, 'geometryType': 'esriGeometryPoint', 'spatialReference': {'wkid': 4326, 'latestWkid': 4326}, 'fields': [{'name': 'CCN', 'type': 'esriFieldTypeString', 'alias': 'CCN', 'length': 8}, {'name': 'REPORT_DAT', 'type': 'esriFieldTypeDate', 'alias': 'REPORT_DATE', 'length': 8}, {'name': 'SHIFT', 'type': 'esriFieldTypeString', 'alias': 'SHIFT', 'length': 50}, {'name': 'METHOD', 'type': 'esriFieldTypeString', 'alias': 'METHOD', 'length': 50}, {'name': 'OFFENSE', 'type': 'esriFieldTypeString', 'alias': 'OFFENSE', 'length': 250}, {'name': 'BLOCK', 'type': 'esriFieldTypeString', 'alias': 'BLOCK', 'length': 100}, {'name': 'XBLOCK', 'type': 'esriFieldTypeDouble', 'alias': 'XBLOCK'}, {'name': 'YBLOCK', 'type': 'esriFieldTypeDouble', 'alias': 'YBLOCK'}, {'name': 'WARD', 'type': 'esriFieldTypeString', 'alias': 'WARD', 'length': 1}, {'name': 'ANC', 'type': 'esriFieldTypeString', 'alias': 'ANC', 'length': 5}, {'name': 'DISTRICT', 'type': 'esriFieldTypeString', 'alias': 'DISTRICT', 'length': 1}, {'name': 'PSA', 'type': 'esriFieldTypeString', 'alias': 'PSA', 'length': 3}, {'name': 'NEIGHBORHOOD_CLUSTER', 'type': 'esriFieldTypeString', 'alias': 'NEIGHBORHOOD_CLUSTER', 'length': 200}, {'name': 'BLOCK_GROUP', 'type': 'esriFieldTypeString', 'alias': 'BLOCK_GROUP', 'length': 20}, {'name': 'CENSUS_TRACT', 'type': 'esriFieldTypeString', 'alias': 'CENSUS_TRACT', 'length': 20}, {'name': 'VOTING_PRECINCT', 'type': 'esriFieldTypeString', 'alias': 'VOTING_PRECINCT', 'length': 25}, {'name': 'LATITUDE', 'type': 'esriFieldTypeDouble', 'alias': 'LATITUDE'}, {'name': 'LONGITUDE', 'type': 'esriFieldTypeDouble', 'alias': 'LONGITUDE'}, {'name': 'BID', 'type': 'esriFieldTypeString', 'alias': 'BID', 'length': 100}, {'name': 'START_DATE', 'type': 'esriFieldTypeDate', 'alias': 'START_DATE', 'length': 8}, {'name': 'END_DATE', 'type': 'esriFieldTypeDate', 'alias': 'END_DATE', 'length': 8}, {'name': 'OBJECTID', 'type': 'esriFieldTypeOID', 'alias': 'OBJECTID'}, {'name': 'OCTO_RECORD_ID', 'type': 'esriFieldTypeString', 'alias': 'OCTO_RECORD_ID', 'length': 25}], 'features': [{'attributes': {'CCN': '20005346', 'REPORT_DAT': 1578606840000, 'SHIFT': 'EVENING', 'METHOD': 'GUN', 'OFFENSE': 'ROBBERY', 'BLOCK': '3501 - 3752 BLOCK OF HAYES STREET NE', 'XBLOCK': 404340.06, 'YBLOCK': 137226.22, 'WARD': '7', 'ANC': '7D', 'DISTRICT': '6', 'PSA': '601', 'NEIGHBORHOOD_CLUSTER': 'Cluster 30', 'BLOCK_GROUP': '009602 2', 'CENSUS_TRACT': '009602', 'VOTING_PRECINCT': 'Precinct 100', 'LATITUDE': 38.9028802339, 'LONGITUDE': -76.9499649287, 'BID': None, 'START_DATE': 1578601946000, 'END_DATE': 1578606992000, 'OBJECTID': 496384972, 'OCTO_RECORD_ID': '20005346-01'}, 'geometry': {'x': -76.94996719678112, 'y': 38.902888024453866}}, {'attributes': {'CCN': '20005351', 'REPORT_DAT': 1578607211000, 'SHIFT': 'EVENING', 'METHOD': 'OTHERS', 'OFFENSE': 'THEFT/OTHER', 'BLOCK': '3000 - 3133 BLOCK OF RHODE ISLAND AVENUE NE', 'XBLOCK': 403053.0, 'YBLOCK': 140739.0, 'WARD': '5', 'ANC': '5C', 'DISTRICT': '5', 'PSA': '503', 'NEIGHBORHOOD_CLUSTER': 'Cluster 24', 'BLOCK_GROUP': '011100 2', 'CENSUS_TRACT': '011100', 'VOTING_PRECINCT': 'Precinct 69', 'LATITUDE': 38.9345299174, 'LONGITUDE': -76.9647873815, 'BID': None, 'START_DATE': 1578604656000, 'END_DATE': 1578604778000, 'OBJECTID': 496384973, 'OCTO_RECORD_ID': '20005351-01'}, 'geometry': {'x': -76.96478965616015, 'y': 38.934537713797845}}, {'attributes': {'CCN': '20005352', 'REPORT ...

# %%
import pandas as pd

csv = pd.read_csv('Contratos_Covid.csv', delimiter=';')
print(csv)
# Out:
#     Valor Total Contrato                                             Insumo  \
# 0         R$ 391.000,00                            Álcool gel 70% de 500ml
# 1         R$ 124.000,00                           Álcool gel  70% de 100ml
# 2          R$ 51.800,00         Cloreto de sódio ; Suplemento para cultura
# 3         R$ 310.000,00                                    Óculos proteção
# 4       R$ 2.280.000,00                       Luva sem látex TAM: P, M e G
# 5       R$ 2.040.000,00                       Luva sem látex TAM: P, M e G
# 6           R$ 7.000,00                                          Sapatilha
# 7          R$ 36.000,00                                               Swab
# 8          R$ 23.400,00                                   Tubo tipo Falcon
# 9       R$ 1.680.000,00                                   Touca hospitalar
# 10        R$ 480.000,00                                  Máscara 3 camadas
# 11      R$ 2.400.000,00                                  Máscara 3 camadas
# 12     R$ 26.100.000,00                       Máscara 3 camadas - Cartucho
# 13         R$ 64.498,80   Soro, tipo : fetal bovino, aspecto físico : so...
# 14         R$ 47.505,72   Solução tampão, características adicionais: li...
# 15          R$ 2.791,70    OLIGONUCLEOTÍDEOS, REAÇÃO DE PCR, ESPECIALMEN...
# 16            R$ 234,00   Microtubo, material: polipropileno, capacidade...
# 17      R$ 3.223.000,00    Suplemento para meio de cultura, tipo: soro f...
# 18      R$ 1.795.000,00               Máscara n95 - Respirador sem válvula
# 19            R$ 419,68   Ponteira laboratório, material: polipropileno,...
# 20      R$ 1.484.000,00                  Avental hospitalar, tamanho único
# 21     R$ 28.680.000,00                                  KIT 10 leitos UTI
# 22     R$ 15.760.000,00    Máscara cirúrgica, material: sms,camadas: 3 c...
# 23        R$ 700.000,00                        Avental hospitalar, tam "G"
# 24     R$ 60.975.600,00                                  KIT 10 LEITOS UTI
# 25      R$ 2.960.000,00    Touca hospitalar ; Luva Latex TAM P, M e G; S...
# 26     R$ 41.600.000,00                                     Máscara tripla
# 27         R$ 14.960,00    ÁGUA, ESTÉRIL, APIROGÊNICA, LIVRE DE DNAse e ...
# 28      R$ 1.330.479,96                                  OLIGONUCLEOTÍDEOS
# 29         R$ 15.000,00                                  OLIGONUCLEOTÍDEOS
# 30        R$ 172.232,53                                  OLIGONUCLEOTÍDEOS
# 31        R$ 360.000,00                                              Touca
# 32         R$ 76.000,00                                 Óculos de Proteção
# 33      R$ 6.680.000,00                        Álcool em gel 70% de  500ml
# 34   US$ 132.000.000,00                    Máscara 3 camadas ; Máscara N95
# 35    R$ 322.550.400,00    Ventilador Pulmonar eletrônico neonatal pediá...
# 36    R$ 258.000.000,00                  VENTILADORES MICROPROCESSADOS iX5
# 37                 Zero      SERVIÇOS DE PROCESSAMENTO DE EXAME TESTES RNA
# 38     R$ 78.000.000,00    Ventilador Pulmonar modelo Servoventilador Ca...
# 39     R$ 10.538.027,52                  Hospital de campanha (200 leitos)
# 40     R$ 72.037.000,00    Ventilador Pulmonar microprocessado LUFT3 ; V...
# 41     R$ 57.000.000,00            Ventilador Pulmonar Microprocessado WL3
